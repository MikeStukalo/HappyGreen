# %% [markdown]
#    In this notebook we use the cleaned dataset from [DataCleaning](DataCleaning.ipynb) to create features for modelling.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle
from sklearn.model_selection import train_test_split

np.random.seed(123)

plt.style.use("seaborn")

# %% [markdown]
# # Features

# %%
# Load the dataframe
df = pd.read_csv("./data/df_clean.csv", index_col=0).reset_index(drop=True)
df.head()
# Out:
#     Time  AX    AY   AZ  GX   GY   GZ  FileNum  ExpPutts  Mark Stage  Id
# 0  21417  56  1023  175 -88 -361 -327        1        30   1.0  Back   1
# 1  21423  83  1019  149 -92 -363 -319        1        30   NaN  Back   1
# 2  21429  69  1006  116 -88 -366 -325        1        30   NaN  Back   1
# 3  21436  75  1008   92 -88 -361 -334        1        30   NaN  Back   1
# 4  21442  81   996   56 -82 -366 -339        1        30   NaN  Back   1

# %% [markdown]
# As we discussed previously, we can divide a putt into two stages: swinging the club back and swinging it forward.

# %%
# Plot swing
tmp = df.loc[df.Id == 2, :]


_ = tmp.AZ.plot()
_ = plt.annotate("Swing back", xy=(27.5,-200), xytext=(25,50), arrowprops=dict(facecolor='black', shrink=0.05))
_ = plt.annotate("Swing forward", xy=(34,-200), xytext=(32,-100), arrowprops=dict(facecolor='black', shrink=0.05))
_ = plt.title("Accelerometer Z: Putt # 2")

# %% [markdown]
# Our assumption is that only swing forward applies force to a ball, so we will use only this part of the swing for creating independent variables.

# %%
df = df.loc[df.Stage == 'Forward', :]

df.head()
# Out:
#      Time  AX    AY   AZ   GX   GY   GZ  FileNum  ExpPutts  Mark    Stage  Id
# 14  21504  12  1108 -444  -92 -367 -334        1        30   2.0  Forward   1
# 15  21511  32  1120 -392  -91 -363 -318        1        30   NaN  Forward   1
# 16  21517 -83   972  106 -103 -358 -297        1        30   NaN  Forward   1
# 17  21523  30  1046   75  -97 -346 -285        1        30   NaN  Forward   1
# 18  21529  29  1044  381  -89 -352 -274        1        30   NaN  Forward   1

# %% [markdown]
# We will use all axes of Accelerometer and Gyroscope in the hope that we can also predict misses that happended to the left or to the right of the hole.
#
# The strategy is to create many summary variables to use them later with L0 regularization as a way of feature selection.
#
# For each axis we calculate the follwoing Variables: Range, Min, Max, Average, and Average of recentered observations. To recenter observations we subtract the miminun value $\bar{X} = \sum \frac{x_i - min(X)}{N}$.
#
# Also, because we have one continous motion, we can roughly approximate derivatives as $\frac{X_T - X_0}{\Delta T}$

# %%
# Function to calculate variables

def CalcVar(x, ts):
    '''
    Calculates variables based on Series of observations (x) and timestampts (ts). Returns Dictionary.
    
    '''
    
    Max= np.max(x)
    Min= np.min(x)
    Range = Max-Min
    Av = np.mean(x)
    AvDem = np.mean(x - Min)
    
    Deriv = (x[-1] - x[0])/(ts[-1] - ts[0])
    
    out = pd.Series({"Range":Range, "Max":Max, "Min":Min, "Mean":Av, "MeanD":AvDem, 'Deriv': Deriv})
    
    
    return out

# %%
# Test function
x = df.loc[df.Id==3, ['AZ','Time']]
CalcVar(x['AZ'].values, x['Time'].values)
# Out:
# Range    1125.0
# Max       516.0
# Min      -609.0
# Mean      -44.8
# MeanD     564.2
# Deriv      45.0
# dtype: float64

# %% [markdown]
# We also create vector distance representation for each sensor

# %%
df['Accel'] = df[['AZ', 'AY', 'AX']].apply(lambda x: np.sqrt(x.iloc[0]**2 + x.iloc[1]**2 + x.iloc[2]**2), axis=1)
df['Gyro'] = df[['GZ', 'GY', 'GX']].apply(lambda x: np.sqrt(x.iloc[0]**2 + x.iloc[1]**2 + x.iloc[2]**2), axis=1)

df.head()
# Out:
#      Time  AX    AY   AZ   GX   GY   GZ  FileNum  ExpPutts  Mark    Stage  Id  \
# 14  21504  12  1108 -444  -92 -367 -334        1        30   2.0  Forward   1
# 15  21511  32  1120 -392  -91 -363 -318        1        30   NaN  Forward   1
# 16  21517 -83   972  106 -103 -358 -297        1        30   NaN  Forward   1
# 17  21523  30  1046   75  -97 -346 -285        1        30   NaN  Forward   1
# 18  21529  29  1044  381  -89 -352 -274        1        30   NaN  Forward   1
#
#           Accel        Gyro
# 14  1193.710183  504.687032
# 15  1187.050125  491.094696
# 16   981.279267  476.426280
# 17  1049.114388  458.639292
# 18  1111.727485  454.863716

# %% [markdown]
# We create a summary table for independent variables by circling through the ids and variables.

# %%
# Set variables
var_list = ['AX', 'AY', 'AZ', 'GX', 'GY', 'GZ', 'Accel', 'Gyro']
all_ids = df.Id.unique()

res = pd.DataFrame()

for i in all_ids:
    
    out1 = pd.DataFrame({"Id":i}, index=[i])
    
    for v in var_list:
        tmp =  df.loc[df.Id==i, [v, 'Time']]
        
        t_ = CalcVar(tmp[v].values, tmp['Time'].values)
        t_.index = [v + "_" + sub for sub in t_.index.values] 
        
              
        t_ = pd.DataFrame(t_).transpose()
        t_['Id'] = i
        
        out1 = out1.merge(t_, on ='Id', how = 'left')
    
    res = res.append(out1, ignore_index=True)
        

res.head()
# Out:
#    Id  AX_Range  AX_Max  AX_Min    AX_Mean    AX_MeanD  AX_Deriv  AY_Range  \
# 0   1     129.0    46.0   -83.0  11.000000   94.000000  1.062500     148.0
# 1   2     173.0    99.0   -74.0  26.166667  100.166667  1.741935     175.0
# 2   3     339.0   291.0   -48.0  75.400000  123.400000  4.040000     312.0
# 3   4      96.0    55.0   -41.0   8.333333   49.333333 -1.419355     177.0
# 4   5     227.0   231.0     4.0  73.750000   69.750000  0.727273     167.0
#
#    AY_Max  AY_Min  ...    Accel_Min   Accel_Mean  Accel_MeanD  Accel_Deriv  \
# 0  1120.0   972.0  ...   981.279267  1115.246055   133.966788    -0.784853
# 1  1130.0   955.0  ...  1110.258528  1150.648937    40.390408    -0.839279
# 2  1150.0   838.0  ...   890.005056  1116.454213   226.449157    -0.902048
# 3  1156.0   979.0  ...  1049.294048  1182.921327   133.627278    -2.360549
# 4  1149.0   982.0  ...  1068.167590  1125.204203    57.036613    -0.088372
#
#    Gyro_Range    Gyro_Max    Gyro_Min   Gyro_Mean  Gyro_MeanD  Gyro_Deriv
# 0   62.675720  504.687032  442.011312  471.287054   29.275742   -1.958616
# 1   43.456776  491.701129  448.244353  467.928756   19.684403   -1.401831
# 2   39.061656  495.278709  456.217054  475.083052   18.865998   -1.562466
# 3   62.198122  502.479850  440.281728  463.761472   23.479744   -1.976895
# 4   65.791242  509.858804  444.067562  470.240758   26.173195   -1.426652
#
# [5 rows x 49 columns]

# %% [markdown]
# # Add distance and Response variable

# %%
# Read response and distance

resp = pd.read_csv("../DataCollect/data/response.csv")
resp.columns.values[0] = 'Id'
resp.head()
# Out:
#    Id  Distance  Result
# 0   1         2       0
# 1   2         2       1
# 2   3         2       1
# 3   4         2       0
# 4   5         2       1

# %% [markdown]
# Initially, we measured distance in feet. However, to address that the distance is measured to precise, we convert in in inches and add random noise of +/- 1 inch.

# %%
resp['Distance_Inch'] = resp['Distance'] * 12 + np.random.uniform(-1,1, size = resp.shape[0])

resp.head()
# Out:
#    Id  Distance  Result  Distance_Inch
# 0   1         2       0      24.392938
# 1   2         2       1      23.572279
# 2   3         2       1      23.453703
# 3   4         2       0      24.102630
# 4   5         2       1      24.438938

# %%
# Merge

df = resp.merge(res, on='Id', how='left')
df.head()
# Out:
#    Id  Distance  Result  Distance_Inch  AX_Range  AX_Max  AX_Min    AX_Mean  \
# 0   1         2       0      24.392938     129.0    46.0   -83.0  11.000000
# 1   2         2       1      23.572279     173.0    99.0   -74.0  26.166667
# 2   3         2       1      23.453703     339.0   291.0   -48.0  75.400000
# 3   4         2       0      24.102630      96.0    55.0   -41.0   8.333333
# 4   5         2       1      24.438938     227.0   231.0     4.0  73.750000
#
#      AX_MeanD  AX_Deriv  ...    Accel_Min   Accel_Mean  Accel_MeanD  \
# 0   94.000000  1.062500  ...   981.279267  1115.246055   133.966788
# 1  100.166667  1.741935  ...  1110.258528  1150.648937    40.390408
# 2  123.400000  4.040000  ...   890.005056  1116.454213   226.449157
# 3   49.333333 -1.419355  ...  1049.294048  1182.921327   133.627278
# 4   69.750000  0.727273  ...  1068.167590  1125.204203    57.036613
#
#    Accel_Deriv  Gyro_Range    Gyro_Max    Gyro_Min   Gyro_Mean  Gyro_MeanD  \
# 0    -0.784853   62.675720  504.687032  442.011312  471.287054   29.275742
# 1    -0.839279   43.456776  491.701129  448.244353  467.928756   19.684403
# 2    -0.902048   39.061656  495.278709  456.217054  475.083052   18.865998
# 3    -2.360549   62.198122  502.479850  440.281728  463.761472   23.479744
# 4    -0.088372   65.791242  509.858804  444.067562  470.240758   26.173195
#
#    Gyro_Deriv
# 0   -1.958616
# 1   -1.401831
# 2   -1.562466
# 3   -1.976895
# 4   -1.426652
#
# [5 rows x 52 columns]

# %%
df.shape
# Out:
# (250, 52)

# %% [markdown]
# # Train, Validation and Test set

# %% [markdown]
# We use stratification by Distance and Result to make sure that our datasets are balanced.

# %%
# Train/test
train, test  = train_test_split(df, test_size=0.3, random_state=123, stratify=df[['Result', 'Distance']])

# %%
# Get validation from test
val, test = train_test_split(test, test_size=0.6, random_state=123, stratify=test[['Result', 'Distance']])

# %%
print(train.shape)
print(val.shape)
print(test.shape)
# Out:
# (175, 52)
# (30, 52)
# (45, 52)

# %% [markdown]
# Remove distance in feet

# %%
train.drop('Distance', axis=1, inplace=True)
val.drop('Distance', axis=1, inplace=True)
test.drop('Distance', axis=1, inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
train.head()
# Out:
#      Id  Result  Distance_Inch  AX_Range  AX_Max  AX_Min    AX_Mean  \
# 146  47       0      48.483724     374.0   254.0  -120.0  52.400000
# 117  18       1      48.043066     166.0    91.0   -75.0  28.000000
# 201   2       1      71.133549     173.0    99.0   -74.0  26.166667
# 156   7       1      60.329745     131.0   129.0    -2.0  80.833333
# 152   3       0      59.573073     339.0   291.0   -48.0  75.400000
#
#        AX_MeanD   AX_Deriv  AY_Range  ...    Accel_Min   Accel_Mean  \
# 146  172.400000  13.120000     200.0  ...  1194.755624  1266.582884
# 117  103.000000   3.720000      99.0  ...  1052.182969  1179.446290
# 201  100.166667   1.741935     175.0  ...  1110.258528  1150.648937
# 156   82.833333   2.000000      66.0  ...  1024.533552  1067.777357
# 152  123.400000   4.040000     312.0  ...   890.005056  1116.454213
#
#      Accel_MeanD  Accel_Deriv  Gyro_Range    Gyro_Max    Gyro_Min   Gyro_Mean  \
# 146    71.827260     4.609239   75.811889  513.345887  437.533999  482.378497
# 117   127.263321    -0.248448   59.785414  512.903500  453.118086  480.624084
# 201    40.390408    -0.839279   43.456776  491.701129  448.244353  467.928756
# 156    43.243805    -1.748867   41.781974  498.776503  456.994530  476.257587
# 152   226.449157    -0.902048   39.061656  495.278709  456.217054  475.083052
#
#      Gyro_MeanD  Gyro_Deriv
# 146   44.844498   -2.999645
# 117   27.505998   -2.391417
# 201   19.684403   -1.401831
# 156   19.263058   -1.189341
# 152   18.865998   -1.562466
#
# [5 rows x 51 columns]

# %%
# Pickle for future use
test.to_pickle("./data/test.pkl")
val.to_pickle("./data/val.pkl")
train.to_pickle("./data/train.pkl")

# %%
# Explore variable to see if there is nothing outstanding

df.describe().transpose()
# Out:
#                count         mean         std          min          25%  \
# Id             250.0    25.500000   14.459818     1.000000    13.000000
# Distance       250.0     4.000000    1.417051     2.000000     3.000000
# Result         250.0     0.520000    0.500602     0.000000     0.000000
# Distance_Inch  250.0    48.005629   17.009859    23.119356    35.616535
# AX_Range       250.0   228.040000  127.865071    50.000000   131.000000
# AX_Max         250.0   177.400000  105.262724    23.000000   109.000000
# AX_Min         250.0   -50.640000   62.501650  -254.000000   -90.000000
# AX_Mean        250.0    50.517024   45.442724   -84.800000    26.166667
# AX_MeanD       250.0   101.157024   53.289851    21.000000    66.000000
# AX_Deriv       250.0     3.291357    4.481736    -5.320000     0.687500
# AY_Range       250.0   215.720000   99.851705    66.000000   137.000000
# AY_Max         250.0  1173.880000   64.633859  1050.000000  1128.000000
# AY_Min         250.0   958.160000   91.247569   692.000000   953.000000
# AY_Mean        250.0  1069.643905   41.045060   999.500000  1037.666667
# AY_MeanD       250.0   111.483905   70.990938    39.166667    61.400000
# AY_Deriv       250.0    -1.789619    2.623148   -11.560000    -3.080000
# AZ_Range       250.0  1215.760000  309.057744   730.000000  1007.000000
# AZ_Max         250.0   637.220000  171.825807   345.000000   507.000000
# AZ_Min         250.0  -578.540000  153.590522 -1043.000000  -659.000000
# AZ_Mean        250.0    39.183635   65.190381  -106.285714    -4.428571
# AZ_MeanD       250.0   617.723635  171.765085   326.000000   492.166667
# AZ_Deriv       250.0    41.968348   16.092493    13.929825    30.052632
# GX_Range       250.0    19.380000    5.893601     4.000000    15.000000
# GX_Max         250.0   -84.500000    5.249785   -97.000000   -88.000000
# GX_Min         250.0  -103.880000    3.986120  -112.000000  -107.000000
# GX_Mean        250.0   -95.499365    3.239862  -105.833333   -97.833333
# GX_MeanD       250.0     8.380635    2.643647     2.000000     6.600000
# GX_Deriv       250.0    -0.463825    0.307991    -1.280000    -0.645161
# GY_Range       250.0    24.320000    8.998974     6.000000    18.000000
# GY_Max         250.0  -342.580000    8.663940  -367.000000  -348.000000
# GY_Min         250.0  -366.900000    7.051873  -381.000000  -372.000000
# GY_Mean        250.0  -353.343167    6.783121  -374.000000  -357.000000
# GY_MeanD       250.0    13.556833    5.377881     2.200000     9.600000
# GY_Deriv       250.0     0.717483    0.332236     0.040000     0.480000
# GZ_Range       250.0    77.860000   17.534831    38.000000    67.000000
# GZ_Max         250.0  -264.660000   14.158611  -288.000000  -274.000000
# GZ_Min         250.0  -342.520000   13.235950  -370.000000  -351.000000
# GZ_Mean        250.0  -299.240071   10.944739  -325.400000  -306.571429
# GZ_MeanD       250.0    43.279929    9.990223    23.400000    38.000000
# GZ_Deriv       250.0     2.588277    0.703525     1.421053     2.040000
# Accel_Range    250.0   232.171766  134.452955    49.886345   130.951229
# Accel_Max      250.0  1270.553237  107.760572  1103.373464  1193.710183
# Accel_Min      250.0  1038.381471  117.323740   722.063709   985.018782
# Accel_Mean     250.0  1181.849092   85.666898  1067.777357  1116.454213
# Accel_MeanD    250.0   143.467621   97.955700    22.924162    60.479154
# Accel_Deriv    250.0    -0.469278    2.487123    -8.162688    -1.680656
# Gyro_Range     250.0    63.295132   14.963048    35.039293    53.994737
# Gyro_Max       250.0   509.031745   10.135741   488.738171   500.780391
# Gyro_Min       250.0   445.736613   12.393802   415.356473   439.081997
# Gyro_Mean      250.0   473.312407    9.125559   451.653906   467.928756
# Gyro_MeanD     250.0    27.575794    7.499809    15.596987    22.861787
# Gyro_Deriv     250.0    -2.088803    0.595600    -3.532297    -2.398234
#
#                        50%          75%          max
# Id               25.500000    38.000000    50.000000
# Distance          4.000000     5.000000     6.000000
# Result            1.000000     1.000000     1.000000
# Distance_Inch    48.069297    60.498466    72.992173
# AX_Range        194.500000   275.000000   651.000000
# AX_Max          147.500000   246.000000   567.000000
# AX_Min          -36.000000    -2.000000    72.000000
# AX_Mean          53.833333    86.428571   150.000000
# AX_MeanD         92.100000   123.400000   305.200000
# AX_Deriv          2.333570     4.400000    17.960000
# AY_Range        200.500000   278.000000   459.000000
# AY_Max         1159.500000  1226.000000  1375.000000
# AY_Min          983.500000  1015.000000  1098.000000
# AY_Mean        1066.166667  1092.428571  1201.800000
# AY_MeanD         87.700000   139.000000   311.857143
# AY_Deriv         -1.467742     0.157895     3.240000
# AZ_Range       1156.500000  1380.000000  2112.000000
# AZ_Max          621.000000   743.000000  1253.000000
# AZ_Min         -572.000000  -469.000000  -322.000000
# AZ_Mean          40.533333    80.000000   234.000000
# AZ_MeanD        605.416667   708.166667  1156.000000
# AZ_Deriv         39.616129    51.560000    84.480000
# GX_Range         19.000000    24.000000    35.000000
# GX_Max          -85.000000   -82.000000   -71.000000
# GX_Min         -103.000000  -101.000000   -94.000000
# GX_Mean         -95.350000   -93.714286   -88.333333
# GX_MeanD          8.183333     9.800000    14.555556
# GX_Deriv         -0.481935    -0.297297     0.400000
# GY_Range         24.000000    30.000000    45.000000
# GY_Max         -343.000000  -336.000000  -324.000000
# GY_Min         -366.500000  -363.000000  -349.000000
# GY_Mean        -353.116667  -348.000000  -335.166667
# GY_MeanD         14.166667    16.625000    26.333333
# GY_Deriv          0.661290     0.920000     1.440000
# GZ_Range         79.500000    91.000000   108.000000
# GZ_Max         -266.000000  -258.000000  -223.000000
# GZ_Min         -341.000000  -334.000000  -316.000000
# GZ_Mean        -300.133333  -291.400000  -270.500000
# GZ_MeanD         43.883333    50.875000    61.333333
# GZ_Deriv          2.550509     3.161290     4.160000
# Accel_Range     213.943545   310.501764   575.488091
# Accel_Max      1259.675398  1313.819242  1701.839887
# Accel_Min      1061.251609  1110.258528  1269.485329
# Accel_Mean     1173.046524  1230.948510  1473.292328
# Accel_MeanD     129.522474   195.475666   388.233927
# Accel_Deriv      -0.765533     0.899540     5.483040
# Gyro_Range       61.731422    74.992949    96.251144
# Gyro_Max        508.390400   517.668813   526.654536
# Gyro_Min        448.295101   454.578926   474.878932
# Gyro_Mean       473.594555   480.624084   492.068602
# Gyro_MeanD       26.376290    31.544409    45.798507
# Gyro_Deriv       -1.976588    -1.578774    -1.189341
